# %%
from pyspark.sql.functions import avg, count, round

# %%
catalog = dbutils.widgets.get("catalog")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 catalog = dbutils.widgets.get("catalog")
#
# File c:\code\dab_project-main\.venv_dbc\Lib\site-packages\databricks\sdk\_widgets\__init__.py:10, in WidgetUtils.get(self, name)
#       9 def get(self, name: str):
# ---> 10     return self._get(name)
#
# File c:\code\dab_project-main\.venv_dbc\Lib\site-packages\databricks\sdk\_widgets\ipywidgets_utils.py:102, in IPyWidgetUtil._get(self, name)
#     101 def _get(self, name: str) -> str:
# --> 102     return self._widgets[name].value
#
# KeyError: 'catalog'

# %%
df = spark.read.table(f"{catalog}.02_silver.jc_citibike")

# %%
df = df.\
    groupBy("trip_start_date", "start_station_name").\
    agg(
    round(avg("trip_duration_mins"),2).alias("avg_trip_duration_mins"),
    count("ride_id").alias("total_trips")
    )

# %%
df.write.\
    mode("overwrite").\
    option("overwriteSchema", "true").\
    saveAsTable(f"{catalog}.03_gold.daily_station_performance")
# Out:
# HBox(children=(IntProgress(value=0, bar_style='success'), Label(value='')))
